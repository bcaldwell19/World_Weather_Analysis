# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library

import requests

# Import the time library

import time

# Import the datetime module from the datetime library

from datetime import datetime

# Import the OpenWeatherMap's API key

from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call

url = (
    "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
    + weather_api_key
)

# %%
# Json Check w/ fake data

city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 53.33,
#   'feels_like': 52.65,
#   'temp_min': 50.95,
#   'temp_max': 55.85,
#   'pressure': 1016,
#   'humidity': 91},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 200},
#  'clouds': {'all': 100},
#  'dt': 1672507706,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1672488798,
#   'sunset': 1672521652},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# keys check

city_weather.json().keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
# description check

city_weather.json()["weather"][0]["description"]
# Out:
# 'overcast clouds'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city

city_data = []

# Print a message to indicate that the data retrieval starts

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1

record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes

    if i % 50 == 0 and i >= 50:
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city

    city_url = url + "&q=" + city.replace(" ", "+")

    # Log the url, record, and set numbers

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count

    record_count += 1

    # Run an API request for each of the cities

    try:
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]

        # Append the city information into the city_data list

        city_data.append(
            {
                "City": city.title(),
                "Lat": city_lat,
                "Lng": city_lng,
                "Current Description": city_weather_description,
                "Max Temp": city_max_temp,
                "Country": city_country,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
            }
        )

    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gurupa
# Processing Record 2 of Set 1 | mantua
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | tambo
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | atambua
# Processing Record 10 of Set 1 | tanjong karang
# City not found. Skipping...
# Processing Record 11 of Set 1 | darhan
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | sturgeon bay
# Processing Record 15 of Set 1 | shizunai
# Processing Record 16 of Set 1 | fairbanks
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | pontianak
# Processing Record 19 of Set 1 | la ronge
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | leh
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | kamenka
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | batsfjord
# Processing Record 30 of Set 1 | enna
# Processing Record 31 of Set 1 | chadan
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | vao
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | mount isa
# Processing Record 36 of Set 1 | vestmannaeyjar
# Processing Record 37 of Set 1 | biak
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | kudahuvadhoo
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | talcahuano
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | kulhudhuffushi
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | markivka
# Processing Record 46 of Set 1 | chabahar
# Processing Record 47 of Set 1 | maneadero
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | praia da vitoria
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | clyde river
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | oriximina
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | rajapolah
# Processing Record 7 of Set 2 | itarema
# Processing Record 8 of Set 2 | kang
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | three hills
# Processing Record 13 of Set 2 | port-gentil
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | gusev
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | nha trang
# Processing Record 20 of Set 2 | camacha
# Processing Record 21 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | pochutla
# Processing Record 25 of Set 2 | gizo
# Processing Record 26 of Set 2 | bilma
# Processing Record 27 of Set 2 | alice springs
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | beloha
# Processing Record 32 of Set 2 | sonoita
# Processing Record 33 of Set 2 | mokrousovo
# Processing Record 34 of Set 2 | arlit
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | leningradskiy
# Processing Record 37 of Set 2 | elko
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | cidreira
# Processing Record 42 of Set 2 | yulara
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | bonnyville
# Processing Record 45 of Set 2 | bathsheba
# Processing Record 46 of Set 2 | broken hill
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | taoudenni
# Processing Record 50 of Set 2 | santo domingo
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | lethem
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | puerto del rosario
# Processing Record 5 of Set 3 | san cristobal
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | kirksville
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | lehtmetsa
# Processing Record 10 of Set 3 | plastun
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 3 | karakol
# Processing Record 16 of Set 3 | yarada
# Processing Record 17 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 3 | sambava
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | north bend
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | kawalu
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | henties bay
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | codrington
# Processing Record 30 of Set 3 | russell
# Processing Record 31 of Set 3 | christchurch
# Processing Record 32 of Set 3 | santa isabel do rio negro
# Processing Record 33 of Set 3 | rio grande
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | amapa
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | algarrobo
# Processing Record 41 of Set 3 | bubaque
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | zhigalovo
# Processing Record 44 of Set 3 | byron bay
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | urdoma
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | vaitape
# Processing Record 49 of Set 3 | soyo
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | punta de piedra
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | rawson
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | fertod
# Processing Record 9 of Set 4 | gornopravdinsk
# Processing Record 10 of Set 4 | anadyr
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 4 | kolyubakino
# Processing Record 14 of Set 4 | narva-joesuu
# Processing Record 15 of Set 4 | omsukchan
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | souillac
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | poum
# Processing Record 23 of Set 4 | letterkenny
# Processing Record 24 of Set 4 | ostrovnoy
# Processing Record 25 of Set 4 | conakry
# Processing Record 26 of Set 4 | senanga
# Processing Record 27 of Set 4 | talara
# Processing Record 28 of Set 4 | savalou
# Processing Record 29 of Set 4 | hovd
# Processing Record 30 of Set 4 | tshikapa
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | sangar
# Processing Record 34 of Set 4 | namatanai
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | santa vitoria do palmar
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | havoysund
# Processing Record 39 of Set 4 | pouebo
# Processing Record 40 of Set 4 | diego de almagro
# Processing Record 41 of Set 4 | polewali
# Processing Record 42 of Set 4 | muros
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | kottapalli
# Processing Record 45 of Set 4 | lerwick
# Processing Record 46 of Set 4 | ekpoma
# Processing Record 47 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 48 of Set 4 | pokrovskoye
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | port blair
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 5 | sulphur springs
# Processing Record 4 of Set 5 | polson
# Processing Record 5 of Set 5 | kapaa
# Processing Record 6 of Set 5 | jiamusi
# Processing Record 7 of Set 5 | guaruja
# Processing Record 8 of Set 5 | kovdor
# Processing Record 9 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 5 | safaga
# Processing Record 12 of Set 5 | cuamba
# Processing Record 13 of Set 5 | vilhena
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | jalu
# Processing Record 16 of Set 5 | mildura
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | kabompo
# Processing Record 19 of Set 5 | puerto penasco
# Processing Record 20 of Set 5 | puerto carreno
# Processing Record 21 of Set 5 | oranjemund
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | bassano
# Processing Record 24 of Set 5 | buala
# Processing Record 25 of Set 5 | presidente dutra
# Processing Record 26 of Set 5 | lokoja
# Processing Record 27 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 5 | carballo
# Processing Record 29 of Set 5 | la palma
# Processing Record 30 of Set 5 | cocorit
# Processing Record 31 of Set 5 | fukue
# Processing Record 32 of Set 5 | vorukh
# Processing Record 33 of Set 5 | paamiut
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | beidao
# Processing Record 36 of Set 5 | raga
# Processing Record 37 of Set 5 | puyang
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | zhangye
# Processing Record 40 of Set 5 | kattivakkam
# Processing Record 41 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 5 | kiunga
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | san policarpo
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | itoman
# Processing Record 48 of Set 5 | ellensburg
# Processing Record 49 of Set 5 | severo-kurilsk
# Processing Record 50 of Set 5 | kavieng
# Processing Record 1 of Set 6 | dovbysh
# Processing Record 2 of Set 6 | axim
# Processing Record 3 of Set 6 | teeli
# Processing Record 4 of Set 6 | ofaqim
# Processing Record 5 of Set 6 | qaanaaq
# Processing Record 6 of Set 6 | luzhou
# Processing Record 7 of Set 6 | ola
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | korla
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | guerrero negro
# Processing Record 12 of Set 6 | bowen
# Processing Record 13 of Set 6 | terrace
# Processing Record 14 of Set 6 | sao filipe
# Processing Record 15 of Set 6 | nan
# Processing Record 16 of Set 6 | san andres
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | straumen
# Processing Record 19 of Set 6 | lembeni
# Processing Record 20 of Set 6 | uyuni
# Processing Record 21 of Set 6 | inhambane
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | constantine
# Processing Record 24 of Set 6 | mwinilunga
# Processing Record 25 of Set 6 | juba
# Processing Record 26 of Set 6 | clarence town
# Processing Record 27 of Set 6 | maridi
# Processing Record 28 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 6 | fortuna
# Processing Record 30 of Set 6 | clearwater
# Processing Record 31 of Set 6 | avera
# Processing Record 32 of Set 6 | alta floresta
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | mangrol
# Processing Record 35 of Set 6 | grand gaube
# Processing Record 36 of Set 6 | siniscola
# Processing Record 37 of Set 6 | sydney
# Processing Record 38 of Set 6 | nautla
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | beira
# Processing Record 41 of Set 6 | bielsko-biala
# Processing Record 42 of Set 6 | can
# Processing Record 43 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 6 | bulaevo
# Processing Record 45 of Set 6 | zhicheng
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | caconda
# Processing Record 48 of Set 6 | solnechnyy
# Processing Record 49 of Set 6 | temyasovo
# Processing Record 50 of Set 6 | hoquiam
# Processing Record 1 of Set 7 | acari
# Processing Record 2 of Set 7 | pervomayskiy
# Processing Record 3 of Set 7 | mayor pablo lagerenza
# Processing Record 4 of Set 7 | verkhoyansk
# Processing Record 5 of Set 7 | yinchuan
# Processing Record 6 of Set 7 | miguel alves
# Processing Record 7 of Set 7 | dudinka
# Processing Record 8 of Set 7 | batagay
# Processing Record 9 of Set 7 | poronaysk
# Processing Record 10 of Set 7 | lujan
# Processing Record 11 of Set 7 | kavali
# Processing Record 12 of Set 7 | mecca
# Processing Record 13 of Set 7 | biskamzha
# Processing Record 14 of Set 7 | general roca
# Processing Record 15 of Set 7 | tumut
# Processing Record 16 of Set 7 | nanakuli
# Processing Record 17 of Set 7 | abong mbang
# Processing Record 18 of Set 7 | orshanka
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | ulaangom
# Processing Record 21 of Set 7 | jumla
# Processing Record 22 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | bardiyah
# Processing Record 25 of Set 7 | los llanos de aridane
# Processing Record 26 of Set 7 | siavonga
# Processing Record 27 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 7 | barcelos
# Processing Record 29 of Set 7 | astana
# Processing Record 30 of Set 7 | nanortalik
# Processing Record 31 of Set 7 | sawakin
# Processing Record 32 of Set 7 | dewa
# Processing Record 33 of Set 7 | road town
# Processing Record 34 of Set 7 | polis
# Processing Record 35 of Set 7 | pangnirtung
# Processing Record 36 of Set 7 | mangai
# Processing Record 37 of Set 7 | orsha
# Processing Record 38 of Set 7 | hinesville
# Processing Record 39 of Set 7 | sioux lookout
# Processing Record 40 of Set 7 | northam
# Processing Record 41 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 7 | treinta y tres
# Processing Record 43 of Set 7 | kampong thum
# Processing Record 44 of Set 7 | orlik
# Processing Record 45 of Set 7 | aswan
# Processing Record 46 of Set 7 | hay river
# Processing Record 47 of Set 7 | san joaquin
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | pathein
# Processing Record 50 of Set 7 | asau
# Processing Record 1 of Set 8 | nouadhibou
# Processing Record 2 of Set 8 | wewak
# Processing Record 3 of Set 8 | trelew
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 8 | agadir
# Processing Record 7 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 8 | yar-sale
# Processing Record 9 of Set 8 | port-cartier
# Processing Record 10 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 8 | novoleushkovskaya
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | miragoane
# Processing Record 16 of Set 8 | linxia
# Processing Record 17 of Set 8 | porto novo
# Processing Record 18 of Set 8 | berlevag
# Processing Record 19 of Set 8 | valle de allende
# Processing Record 20 of Set 8 | mar del plata
# Processing Record 21 of Set 8 | chuy
# Processing Record 22 of Set 8 | huilong
# Processing Record 23 of Set 8 | kifri
# Processing Record 24 of Set 8 | taman
# Processing Record 25 of Set 8 | pouembout
# Processing Record 26 of Set 8 | ketchikan
# Processing Record 27 of Set 8 | concordia
# Processing Record 28 of Set 8 | salimpur
# Processing Record 29 of Set 8 | tucuma
# Processing Record 30 of Set 8 | mackenzie
# Processing Record 31 of Set 8 | desaguadero
# Processing Record 32 of Set 8 | brae
# Processing Record 33 of Set 8 | kalmunai
# Processing Record 34 of Set 8 | nouakchott
# Processing Record 35 of Set 8 | kahama
# Processing Record 36 of Set 8 | aripuana
# Processing Record 37 of Set 8 | moose factory
# Processing Record 38 of Set 8 | morondava
# Processing Record 39 of Set 8 | west wendover
# Processing Record 40 of Set 8 | khash
# Processing Record 41 of Set 8 | igarka
# Processing Record 42 of Set 8 | mount gambier
# Processing Record 43 of Set 8 | nome
# Processing Record 44 of Set 8 | puerto baquerizo moreno
# Processing Record 45 of Set 8 | caloto
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | faurei
# Processing Record 48 of Set 8 | takoradi
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | lanzhou
# Processing Record 1 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 9 | evensk
# Processing Record 3 of Set 9 | nizwa
# Processing Record 4 of Set 9 | linjiang
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 9 | borogontsy
# Processing Record 8 of Set 9 | aliwal north
# Processing Record 9 of Set 9 | emerald
# Processing Record 10 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 11 of Set 9 | olinda
# Processing Record 12 of Set 9 | marsh harbour
# Processing Record 13 of Set 9 | malpe
# Processing Record 14 of Set 9 | am timan
# Processing Record 15 of Set 9 | luau
# Processing Record 16 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 9 | dungarpur
# Processing Record 19 of Set 9 | hudson bay
# Processing Record 20 of Set 9 | pervoye maya
# Processing Record 21 of Set 9 | comodoro rivadavia
# Processing Record 22 of Set 9 | venice
# Processing Record 23 of Set 9 | elmina
# Processing Record 24 of Set 9 | dicabisagan
# Processing Record 25 of Set 9 | geraldton
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | sao joao do piaui
# Processing Record 28 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 9 | aksarka
# Processing Record 30 of Set 9 | pemberton
# Processing Record 31 of Set 9 | sanok
# Processing Record 32 of Set 9 | juegang
# Processing Record 33 of Set 9 | ndele
# Processing Record 34 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 35 of Set 9 | angoram
# Processing Record 36 of Set 9 | dufftown
# Processing Record 37 of Set 9 | alexandria
# Processing Record 38 of Set 9 | westport
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | bristol
# Processing Record 41 of Set 9 | umm kaddadah
# Processing Record 42 of Set 9 | van buren
# Processing Record 43 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 9 | baghdogra
# Processing Record 45 of Set 9 | pangai
# Processing Record 46 of Set 9 | lopatyn
# Processing Record 47 of Set 9 | kyaikkami
# Processing Record 48 of Set 9 | roebourne
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | opuwo
# Processing Record 1 of Set 10 | eureka
# Processing Record 2 of Set 10 | hermagor
# Processing Record 3 of Set 10 | makung
# City not found. Skipping...
# Processing Record 4 of Set 10 | aransas pass
# Processing Record 5 of Set 10 | leander
# Processing Record 6 of Set 10 | nanzhang
# Processing Record 7 of Set 10 | svetlyy
# Processing Record 8 of Set 10 | madaoua
# Processing Record 9 of Set 10 | luderitz
# Processing Record 10 of Set 10 | vredendal
# Processing Record 11 of Set 10 | marystown
# Processing Record 12 of Set 10 | ankara
# Processing Record 13 of Set 10 | kichera
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | peniche
# Processing Record 16 of Set 10 | santander jimenez
# Processing Record 17 of Set 10 | maragogi
# Processing Record 18 of Set 10 | firozpur
# Processing Record 19 of Set 10 | ochakiv
# Processing Record 20 of Set 10 | cayenne
# Processing Record 21 of Set 10 | jinxiang
# Processing Record 22 of Set 10 | sarankhola
# Processing Record 23 of Set 10 | playas
# Processing Record 24 of Set 10 | ballina
# Processing Record 25 of Set 10 | kavaratti
# Processing Record 26 of Set 10 | manoel urbano
# Processing Record 27 of Set 10 | bandarbeyla
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | kencong
# Processing Record 30 of Set 10 | gazojak
# Processing Record 31 of Set 10 | bonavista
# Processing Record 32 of Set 10 | dukat
# Processing Record 33 of Set 10 | palmer
# Processing Record 34 of Set 10 | victoria point
# Processing Record 35 of Set 10 | harper
# Processing Record 36 of Set 10 | khasan
# Processing Record 37 of Set 10 | meulaboh
# Processing Record 38 of Set 10 | gushikawa
# Processing Record 39 of Set 10 | langfang
# Processing Record 40 of Set 10 | san jeronimo
# Processing Record 41 of Set 10 | muzhi
# Processing Record 42 of Set 10 | svetlogorsk
# Processing Record 43 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 44 of Set 10 | eyrarbakki
# Processing Record 45 of Set 10 | yuzawa
# Processing Record 46 of Set 10 | roches noires
# City not found. Skipping...
# Processing Record 47 of Set 10 | hit
# Processing Record 48 of Set 10 | brescia
# Processing Record 49 of Set 10 | juneau
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | gat
# Processing Record 2 of Set 11 | laranjeiras do sul
# Processing Record 3 of Set 11 | tottori
# Processing Record 4 of Set 11 | kaeo
# Processing Record 5 of Set 11 | jinchang
# Processing Record 6 of Set 11 | touros
# Processing Record 7 of Set 11 | kidal
# Processing Record 8 of Set 11 | bada
# Processing Record 9 of Set 11 | riyadh
# Processing Record 10 of Set 11 | salta
# Processing Record 11 of Set 11 | portland
# Processing Record 12 of Set 11 | coquimbo
# Processing Record 13 of Set 11 | sungairaya
# Processing Record 14 of Set 11 | cap malheureux
# Processing Record 15 of Set 11 | husavik
# Processing Record 16 of Set 11 | plyussa
# Processing Record 17 of Set 11 | tolstoy-yurt
# Processing Record 18 of Set 11 | sao paulo de olivenca
# Processing Record 19 of Set 11 | zhuzhou
# Processing Record 20 of Set 11 | noshiro
# Processing Record 21 of Set 11 | grand-santi
# Processing Record 22 of Set 11 | kitimat
# Processing Record 23 of Set 11 | bairiki
# Processing Record 24 of Set 11 | daru
# Processing Record 25 of Set 11 | east london
# Processing Record 26 of Set 11 | korhogo
# Processing Record 27 of Set 11 | jutai
# Processing Record 28 of Set 11 | chimoio
# Processing Record 29 of Set 11 | paita
# Processing Record 30 of Set 11 | krasnoobsk
# Processing Record 31 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 11 | mamallapuram
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | shetpe
# Processing Record 35 of Set 11 | lac du bonnet
# Processing Record 36 of Set 11 | honningsvag
# Processing Record 37 of Set 11 | normandin
# Processing Record 38 of Set 11 | tuban
# Processing Record 39 of Set 11 | ceuta
# Processing Record 40 of Set 11 | esmeraldas
# Processing Record 41 of Set 11 | maceio
# Processing Record 42 of Set 11 | te anau
# Processing Record 43 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 11 | half moon bay
# Processing Record 45 of Set 11 | port lincoln
# Processing Record 46 of Set 11 | luwuk
# Processing Record 47 of Set 11 | coahuayana
# Processing Record 48 of Set 11 | egvekinot
# Processing Record 49 of Set 11 | ocos
# Processing Record 50 of Set 11 | dubovka
# Processing Record 1 of Set 12 | manga
# Processing Record 2 of Set 12 | redlands
# Processing Record 3 of Set 12 | pisco
# Processing Record 4 of Set 12 | maracaju
# Processing Record 5 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 12 | benguela
# Processing Record 7 of Set 12 | paka
# Processing Record 8 of Set 12 | bendigo
# Processing Record 9 of Set 12 | aykhal
# Processing Record 10 of Set 12 | sola
# Processing Record 11 of Set 12 | waspan
# Processing Record 12 of Set 12 | waipawa
# Processing Record 13 of Set 12 | lawrence
# Processing Record 14 of Set 12 | ouro preto
# Processing Record 15 of Set 12 | iona
# Processing Record 16 of Set 12 | virginia beach
# Processing Record 17 of Set 12 | yaan
# Processing Record 18 of Set 12 | butwal
# Processing Record 19 of Set 12 | port macquarie
# Processing Record 20 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 21 of Set 12 | jejuri
# Processing Record 22 of Set 12 | quatre cocos
# Processing Record 23 of Set 12 | malino
# Processing Record 24 of Set 12 | bargarh
# Processing Record 25 of Set 12 | campoverde
# Processing Record 26 of Set 12 | marawi
# Processing Record 27 of Set 12 | jember
# Processing Record 28 of Set 12 | kodinsk
# Processing Record 29 of Set 12 | impfondo
# Processing Record 30 of Set 12 | ust-nera
# Processing Record 31 of Set 12 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 32 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 33 of Set 12 | soc trang
# Processing Record 34 of Set 12 | najran
# Processing Record 35 of Set 12 | black river
# Processing Record 36 of Set 12 | aklavik
# Processing Record 37 of Set 12 | naliya
# Processing Record 38 of Set 12 | deputatskiy
# Processing Record 39 of Set 12 | natchitoches
# Processing Record 40 of Set 12 | belyy yar
# Processing Record 41 of Set 12 | lampa
# Processing Record 42 of Set 12 | innisfail
# Processing Record 43 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 44 of Set 12 | turukhansk
# Processing Record 45 of Set 12 | nueve de julio
# Processing Record 46 of Set 12 | tahe
# Processing Record 47 of Set 12 | okhotsk
# Processing Record 48 of Set 12 | maniitsoq
# Processing Record 49 of Set 12 | severodvinsk
# Processing Record 50 of Set 12 | steinbach
# Processing Record 1 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 13 | komsomolskiy
# Processing Record 3 of Set 13 | koltubanovskiy
# Processing Record 4 of Set 13 | honiara
# Processing Record 5 of Set 13 | oranjestad
# Processing Record 6 of Set 13 | qaqortoq
# Processing Record 7 of Set 13 | kyrylivka
# Processing Record 8 of Set 13 | tres picos
# Processing Record 9 of Set 13 | ucluelet
# Processing Record 10 of Set 13 | kurilsk
# Processing Record 11 of Set 13 | strezhevoy
# Processing Record 12 of Set 13 | okato
# Processing Record 13 of Set 13 | russellville
# Processing Record 14 of Set 13 | vila velha
# Processing Record 15 of Set 13 | tilichiki
# Processing Record 16 of Set 13 | orodara
# Processing Record 17 of Set 13 | marzuq
# Processing Record 18 of Set 13 | lasa
# Processing Record 19 of Set 13 | santa cruz de tenerife
# Processing Record 20 of Set 13 | tazovskiy
# Processing Record 21 of Set 13 | pangody
# Processing Record 22 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 23 of Set 13 | yabrud
# Processing Record 24 of Set 13 | zhuhai
# Processing Record 25 of Set 13 | mananara
# Processing Record 26 of Set 13 | danville
# Processing Record 27 of Set 13 | kwekwe
# Processing Record 28 of Set 13 | gravdal
# Processing Record 29 of Set 13 | flinders
# Processing Record 30 of Set 13 | sakakah
# Processing Record 31 of Set 13 | cabedelo
# Processing Record 32 of Set 13 | aden
# Processing Record 33 of Set 13 | sosua
# Processing Record 34 of Set 13 | sandnessjoen
# Processing Record 35 of Set 13 | freeport
# Processing Record 36 of Set 13 | siderno
# Processing Record 37 of Set 13 | jasrana
# Processing Record 38 of Set 13 | udachnyy
# Processing Record 39 of Set 13 | vostok
# Processing Record 40 of Set 13 | la libertad
# Processing Record 41 of Set 13 | kulu
# Processing Record 42 of Set 13 | grajau
# Processing Record 43 of Set 13 | pyaozerskiy
# Processing Record 44 of Set 13 | san quintin
# Processing Record 45 of Set 13 | kasra
# City not found. Skipping...
# Processing Record 46 of Set 13 | the valley
# Processing Record 47 of Set 13 | kloulklubed
# Processing Record 48 of Set 13 | altona
# Processing Record 49 of Set 13 | kutno
# Processing Record 50 of Set 13 | mokhsogollokh
# Processing Record 1 of Set 14 | tastur
# Processing Record 2 of Set 14 | gilbues
# Processing Record 3 of Set 14 | buraydah
# Processing Record 4 of Set 14 | sokoto
# Processing Record 5 of Set 14 | nara
# Processing Record 6 of Set 14 | pedregulho
# Processing Record 7 of Set 14 | colesberg
# Processing Record 8 of Set 14 | bahia blanca
# Processing Record 9 of Set 14 | khani
# Processing Record 10 of Set 14 | meadow lake
# Processing Record 11 of Set 14 | shirokiy
# Processing Record 12 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 14 of Set 14 | indian head
# Processing Record 15 of Set 14 | teacapan
# Processing Record 16 of Set 14 | tuatapere
# Processing Record 17 of Set 14 | saint-augustin
# Processing Record 18 of Set 14 | magistralnyy
# Processing Record 19 of Set 14 | hamilton
# Processing Record 20 of Set 14 | miguel hidalgo
# Processing Record 21 of Set 14 | lamu
# Processing Record 22 of Set 14 | marsa matruh
# Processing Record 23 of Set 14 | saint-claude
# Processing Record 24 of Set 14 | jardim
# Processing Record 25 of Set 14 | asfi
# Processing Record 26 of Set 14 | wynyard
# Processing Record 27 of Set 14 | ugoofaaru
# Processing Record 28 of Set 14 | svarstad
# Processing Record 29 of Set 14 | port hardy
# Processing Record 30 of Set 14 | sao felix do xingu
# Processing Record 31 of Set 14 | ikwiriri
# Processing Record 32 of Set 14 | navrongo
# Processing Record 33 of Set 14 | hendaye
# Processing Record 34 of Set 14 | bintulu
# Processing Record 35 of Set 14 | krasnogorsk
# Processing Record 36 of Set 14 | yancheng
# Processing Record 37 of Set 14 | zatoka
# Processing Record 38 of Set 14 | pertuis
# Processing Record 39 of Set 14 | murray bridge
# Processing Record 40 of Set 14 | san estanislao
# Processing Record 41 of Set 14 | tieling
# Processing Record 42 of Set 14 | belmonte
# Processing Record 43 of Set 14 | semporna
# Processing Record 44 of Set 14 | maple creek
# Processing Record 45 of Set 14 | baykit
# Processing Record 46 of Set 14 | nueva loja
# Processing Record 47 of Set 14 | pierre
# Processing Record 48 of Set 14 | alenquer
# Processing Record 49 of Set 14 | lensk
# Processing Record 50 of Set 14 | khandyga
# Processing Record 1 of Set 15 | cozumel
# Processing Record 2 of Set 15 | mount darwin
# Processing Record 3 of Set 15 | fare
# Processing Record 4 of Set 15 | havre
# Processing Record 5 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 6 of Set 15 | puerto leguizamo
# Processing Record 7 of Set 15 | sofiyivka
# Processing Record 8 of Set 15 | burns lake
# Processing Record 9 of Set 15 | kutum
# Processing Record 10 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 15 | yumen
# Processing Record 12 of Set 15 | gannan
# Processing Record 13 of Set 15 | barinas
# Processing Record 14 of Set 15 | ambovombe
# Processing Record 15 of Set 15 | ekhabi
# Processing Record 16 of Set 15 | moengo
# Processing Record 17 of Set 15 | naze
# Processing Record 18 of Set 15 | coihaique
# Processing Record 19 of Set 15 | forest grove
# Processing Record 20 of Set 15 | srivardhan
# Processing Record 21 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 15 | matara
# Processing Record 23 of Set 15 | rongcheng
# Processing Record 24 of Set 15 | sao borja
# Processing Record 25 of Set 15 | weymouth
# Processing Record 26 of Set 15 | teguldet
# Processing Record 27 of Set 15 | keetmanshoop
# Processing Record 28 of Set 15 | xining
# Processing Record 29 of Set 15 | duz
# City not found. Skipping...
# Processing Record 30 of Set 15 | bratsk
# Processing Record 31 of Set 15 | palm beach
# Processing Record 32 of Set 15 | leirvik
# Processing Record 33 of Set 15 | chitral
# Processing Record 34 of Set 15 | bosaso
# Processing Record 35 of Set 15 | rio gallegos
# Processing Record 36 of Set 15 | chulumani
# Processing Record 37 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 15 | tuy hoa
# Processing Record 39 of Set 15 | conceicao do araguaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data

city_data_df.head(10)
# Out:
#            City      Lat       Lng      Current Description  Max Temp Country  \
# 0        Gurupa  -1.4050  -51.6400          overcast clouds     90.55      BR
# 1        Mantua  45.1667   10.7833          overcast clouds     50.99      IT
# 2       Ushuaia -54.8000  -68.3000               light rain     51.46      AR
# 3        Torbay  47.6666  -52.7314  light intensity drizzle     43.57      CA
# 4  Norman Wells  65.2820 -126.8329            broken clouds    -11.16      CA
# 5  Punta Arenas -53.1500  -70.9167               light rain     59.02      CL
# 6         Tambo -14.8000  -73.9167               light rain     42.12      PE
# 7   New Norfolk -42.7826  147.0587               few clouds     60.93      AU
# 8       Atambua  -9.1061  124.8925               light rain     73.65      ID
# 9        Darhan  49.4867  105.9228            broken clouds    -13.40      MN
#
#    Humidity  Cloudiness  Wind Speed
# 0        48          97        4.07
# 1        89         100        1.01
# 2        62          75        6.91
# 3        94         100       28.77
# 4        77          75        3.44
# 5        58           0       14.97
# 6        75         100        9.19
# 7        65          18        2.39
# 8        90         100        6.40
# 9       100          63        4.18

# %%
# Display the DataFrame's column names using the columns Pandas function

city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Current Description', 'Max Temp', 'Country',
#        'Humidity', 'Cloudiness', 'Wind Speed'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = [
    "City",
    "Country",
    "Lat",
    "Lng",
    "Max Temp",
    "Humidity",
    "Cloudiness",
    "Wind Speed",
    "Current Description",
]


# Recreate the DataFrame by using the new column order

city_data_df = city_data_df[new_column_order]

# Display sample data

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Gurupa      BR  -1.4050  -51.6400     90.55        48          97
# 1        Mantua      IT  45.1667   10.7833     50.99        89         100
# 2       Ushuaia      AR -54.8000  -68.3000     51.46        62          75
# 3        Torbay      CA  47.6666  -52.7314     43.57        94         100
# 4  Norman Wells      CA  65.2820 -126.8329    -11.16        77          75
# 5  Punta Arenas      CL -53.1500  -70.9167     59.02        58           0
# 6         Tambo      PE -14.8000  -73.9167     42.12        75         100
# 7   New Norfolk      AU -42.7826  147.0587     60.93        65          18
# 8       Atambua      ID  -9.1061  124.8925     73.65        90         100
# 9        Darhan      MN  49.4867  105.9228    -13.40       100          63
#
#    Wind Speed      Current Description
# 0        4.07          overcast clouds
# 1        1.01          overcast clouds
# 2        6.91               light rain
# 3       28.77  light intensity drizzle
# 4        3.44            broken clouds
# 5       14.97               light rain
# 6        9.19               light rain
# 7        2.39               few clouds
# 8        6.40               light rain
# 9        4.18            broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function

city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name

output_data_file = "Weather_data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
